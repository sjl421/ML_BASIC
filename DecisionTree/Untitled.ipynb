# %% [markdown]
# # 决策树
#
# ![决策树示意图（摘抄自周志华 西瓜书）](attachment:image.png)
#
# - 长方形代表**判断模块**。从判断模块引出的左右箭头称为 **分支**，它可以到达另一个判断模块或终止模块。一般来说，每个有效的特征就是一个判断模块
# - 椭圆形代表**终止模块**，表示已经得到结论，可以终止运行
#
# 决策树的主要任务：通过训练集构建一棵决策树。实际上就是如何组织判断模块。
#
# 《机器学习实战》中使用 ID3 算法划分数据集
